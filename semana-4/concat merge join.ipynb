# %%
#concat merge join

import pandas as pd

pd.options.display.max_columns = None

# %%
df_2000 = pd.read_csv("datos/survey2000.csv", index_col = 0).reset_index()
df_2001 = pd.read_csv("datos/survey2001.csv", index_col = 0).reset_index()
df_2002 = pd.read_csv("datos/survey2002.csv", index_col = 0).reset_index()

# %%
#ignore_index = True, ignora los indices 

df_2000.head()
# Out:
#    index  record_id  month  day  year  plot_id species_id sex  \
# 0  30158      30159      1    8  2000        1         PP   F
# 1  30159      30160      1    8  2000        1         DO   M
# 2  30160      30161      1    8  2000        1         PP   F
# 3  30161      30162      1    8  2000        1         DM   M
# 4  30162      30163      1    8  2000        1         PP   M
#
#    hindfoot_length  weight
# 0             22.0    17.0
# 1             35.0    53.0
# 2             21.0    17.0
# 3             36.0    50.0
# 4             20.0    16.0

# %%
id_ = pd.Series(range(1552))
df_concat1 = pd.concat([df_2000, id_], axis = 1 )
df_concat1
# Out:
#       index  record_id  month  day  year  plot_id species_id  sex  \
# 0     30158      30159      1    8  2000        1         PP    F
# 1     30159      30160      1    8  2000        1         DO    M
# 2     30160      30161      1    8  2000        1         PP    F
# 3     30161      30162      1    8  2000        1         DM    M
# 4     30162      30163      1    8  2000        1         PP    M
# ...     ...        ...    ...  ...   ...      ...        ...  ...
# 1547  31705      31706     12   23  2000       15         OT    F
# 1548  31706      31707     12   23  2000       15         OT    M
# 1549  31707      31708     12   23  2000        5        NaN  NaN
# 1550  31708      31709     12   23  2000       10        NaN  NaN
# 1551  31709      31710     12   23  2000       16        NaN  NaN
#
#       hindfoot_length  weight     0
# 0                22.0    17.0     0
# 1                35.0    53.0     1
# 2                21.0    17.0     2
# 3                36.0    50.0     3
# 4                20.0    16.0     4
# ...               ...     ...   ...
# 1547             21.0    25.0  1547
# 1548             20.0    19.0  1548
# 1549              NaN     NaN  1549
# 1550              NaN     NaN  1550
# 1551              NaN     NaN  1551
#
# [1552 rows x 11 columns]

# %% [markdown]
# #MERGE !
#
# Sintaxis:
#
# dataframe1.merge(dataframe2, how='inner', on, left_on=None, right_on=None)

# %%
df_species = pd.read_csv('datos/species.csv')
df_species.head(2)
# Out:
#   species_id             genus    species    taxa
# 0         AB        Amphispiza  bilineata    Bird
# 1         AH  Ammospermophilus    harrisi  Rodent

# %%
df_2000.head(2)
# Out:
#    index  record_id  month  day  year  plot_id species_id sex  \
# 0  30158      30159      1    8  2000        1         PP   F
# 1  30159      30160      1    8  2000        1         DO   M
#
#    hindfoot_length  weight
# 0             22.0    17.0
# 1             35.0    53.0

# %%
mergeado_inner = df_2000.merge(df_species, on = 'species_id')
mergeado_inner.head(2)
# Out:
#    index  record_id  month  day  year  plot_id species_id sex  \
# 0  30158      30159      1    8  2000        1         PP   F
# 1  30160      30161      1    8  2000        1         PP   F
#
#    hindfoot_length  weight        genus       species    taxa
# 0             22.0    17.0  Chaetodipus  penicillatus  Rodent
# 1             21.0    17.0  Chaetodipus  penicillatus  Rodent

# %% [markdown]
# # 📌 esto es lo mismo que lo anterior:
#
# mergeado_inner2 = df_2002.merge(df_species, left_on = "species_id",
#                                right_on = "species_id")
# mergeado_inner2.head()

# %%
#para unir alguna columna no todas. ahí le digo la columna que nos traemos + la del identifier

mergeado_inner2 = df_2000.merge(df_species[['species_id','genus']], on = 'species_id')
mergeado_inner2
# Out:
#       index  record_id  month  day  year  plot_id species_id  sex  \
# 0     30158      30159      1    8  2000        1         PP    F
# 1     30160      30161      1    8  2000        1         PP    F
# 2     30162      30163      1    8  2000        1         PP    M
# 3     30164      30165      1    8  2000        1         PP    F
# 4     30165      30166      1    8  2000        1         PP    M
# ...     ...        ...    ...  ...   ...      ...        ...  ...
# 1504  31563      31564     11   26  2000        3         PE    M
# 1505  31607      31608     11   26  2000       24         PE    M
# 1506  31608      31609     11   26  2000       24         PE    M
# 1507  31664      31665     12   22  2000       24         PE    M
# 1508  30985      30986      7    1  2000        7         PX  NaN
#
#       hindfoot_length  weight        genus
# 0                22.0    17.0  Chaetodipus
# 1                21.0    17.0  Chaetodipus
# 2                20.0    16.0  Chaetodipus
# 3                22.0    15.0  Chaetodipus
# 4                23.0    19.0  Chaetodipus
# ...               ...     ...          ...
# 1504             20.0    23.0   Peromyscus
# 1505             19.0    16.0   Peromyscus
# 1506             21.0    20.0   Peromyscus
# 1507             20.0    23.0   Peromyscus
# 1508              NaN     NaN  Chaetodipus
#
# [1509 rows x 11 columns]

# %%
mergeado_izq = pd.merge(left=df_2002, right=df_species, how='left',
                        left_on='species_id', right_on='species_id')

mergeado_izq.head()
# Out:
#    index  record_id  month  day  year  plot_id species_id  sex  \
# 0  33320      33321      1   12  2002        1         DM    M
# 1  33321      33322      1   12  2002        1         DO    M
# 2  33322      33323      1   12  2002        1         PB    M
# 3  33323      33324      1   12  2002        1         AB  NaN
# 4  33324      33325      1   12  2002        1         DO    M
#
#    hindfoot_length  weight        genus    species    taxa
# 0             38.0    44.0    Dipodomys   merriami  Rodent
# 1             37.0    58.0    Dipodomys      ordii  Rodent
# 2             28.0    45.0  Chaetodipus    baileyi  Rodent
# 3              NaN     NaN   Amphispiza  bilineata    Bird
# 4             35.0    29.0    Dipodomys      ordii  Rodent

# %%
df_species.set_index("species_id", inplace = True)
df_species.head(2)
# Out:
#                        genus    species    taxa
# species_id
# AB                Amphispiza  bilineata    Bird
# AH          Ammospermophilus    harrisi  Rodent

# %%
#JOIN

df_join = df_2002.join(df_species, on = 'species_id') #how, suffix, lsuffix, rsuffix. 
df_join.head(2)
# Out:
#    index  record_id  month  day  year  plot_id species_id sex  \
# 0  33320      33321      1   12  2002        1         DM   M
# 1  33321      33322      1   12  2002        1         DO   M
#
#    hindfoot_length  weight      genus   species    taxa
# 0             38.0    44.0  Dipodomys  merriami  Rodent
# 1             37.0    58.0  Dipodomys     ordii  Rodent
